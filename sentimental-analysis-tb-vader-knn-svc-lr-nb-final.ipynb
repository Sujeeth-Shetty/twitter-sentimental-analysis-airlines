# %%
import pandas as pd
import numpy as np
import nltk
import io
    
df = pd.read_csv(r'D:\Travelytics Project\Data\Airline Tweets.csv',encoding='utf-8-sig')


#New unlabeled Dataset
df_new_data = pd.read_csv(u'D:\Travelytics Project\Data\Preprocessed Tweet Data.csv')
#df_fresh_data= df_new_data[["Text"]]

# %%
'''Textblob sentiment analysis
Code was used from:
https://towardsdatascience.com/having-fun-with-textblob-7e9eed783d3f
https://stackoverflow.com/questions/43485469/apply-textblob-in-for-each-row-of-a-dataframe
'''

from textblob import TextBlob

#replace null values with empty space
noNull = df['Text'].fillna("")

df['sentiment'] = noNull.apply(lambda tweet: TextBlob(tweet).sentiment)

df
# Out:
#      Unnamed: 0  number keyword  \
# 0      0.943430   65789      TT
# 1      0.970177   49400      NK
# 2      0.143541   60959     TOM
# 3      0.360187   77607      VA
# 4      0.779308   58487     TOM
# 5      0.359184   77943      VA
# 6      0.153355   86771      WN
# 7      0.788929   46885      LS
# 8      0.909354   22436      BE
# 9      0.094547   72338      UA
# 10     0.160353   16399      B6
# 11     0.227760   52091      QF
# 12     0.629340   65344      TT
# 13     0.189803   60377     TOM
# 14     0.918695    1581      AA
# 15     0.502972   54854      TO
# 16     0.216359   22399      BE
# 17     0.409520   15645      AS
# 18     0.910300   45944      LS
# 19     0.096877    5540      AA
# 20     0.536603   45306      LS
# 21     0.131978   62805     TOM
# 22     0.171452   12373      AF
# 23     0.951226   52094      QF
# 24     0.668162     811      AA
# 25     0.806601   11809      AF
# 26     0.661338   83304      W6
# 27     0.967721   68383      U2
# 28     0.667780    7503      AC
# 29     0.169100   55744      TO
# ..          ...     ...     ...
# 293    0.713540   14489      AS
# 294    0.771143   48281      LS
# 295    0.367883   60048     TOM
# 296    0.181775   77281      VA
# 297    0.991126   65130      TT
# 298    0.243927   84326      W6
# 299    0.280581   33984      FR
# 300    0.332174    7005      AC
# 301    0.648780   84521      W6
# 302    0.626496   84160      W6
# 303    0.662308   87809      WN
# 304    0.570786   88396      WN
# 305    0.088233   45519      LS
# 306    0.412121    5212      AA
# 307    0.932134   16202      B6
# 308    0.363049   61827     TOM
# 309    0.272725    7605      AC
# 310    0.587596   18822      B6
# 311    0.520768   50257      NK
# 312    0.826819   11803      AF
# 313    0.971511   15251      AS
# 314    0.079147   63374     TOM
# 315    0.117393    5936      AA
# 316    0.769756   50964      NK
# 317    0.519524   80292      VY
# 318    0.510298   15909      AS
# 319    0.703480   63020     TOM
# 320    0.085105   58046     TOM
# 321    0.260572   42866      LH
# 322    0.299976   76133      UX
#
#                                                   Text  \
# 0     Hi there  the best team to assist you is our ...
# 1     We re awfully sorry to hear about that  Pleas...
# 2    RT   In #Namibia  Melissa and Anna Marie found...
# 3     We re sorry to hear this Peter  We would reco...
# 4    RT   The Q  #TUIResults are out and show signi...
# 5     Hi Olan  we are so pleased to hear this feedb...
# 6     Hi there  On May          we will open our sc...
# 7     Sorry to hear that  We do hope to see you aga...
# 8     Hi Charlotte  thanks for getting in touch  I ...
# 9     We re sorry for the disruption  Shea  Can you...
# 10    That s disappointing  We can issue a     cred...
# 11    Perfection on a plate  We enjoyed having you ...
# 12    Our thoughts are with you Walter  keep fighti...
# 13   We ve launched our brand new Investor Relation...
# 14    We love having you fly with us and will gladl...
# 15    Hello  I am sorry for the inconveniences  Can...
# 16    Thanks for confirming this with me Emma  I ve...
# 17    We re sorry to hear about any frustration  If...
# 18    Thanks for getting back to us  we would recom...
# 19    We want all of our customers to feel welcome ...
# 20    Hi Laura  If you don t cancel the individual ...
# 21   Family Holiday Association launches     for   ...
# 22        If your query is regarding your trip  ple...
# 23    This isn t what we like to hear Jimmy  Can yo...
# 24    We re so sorry for the extra travel time toda...
# 25    Hello   not a problem  Send us a DM confirmin...
# 26    Hey Jose  since those services are different ...
# 27    Hi Justin  thanks for getting in touch  I m n...
# 28    Please DM us your booking details so we may a...
# 29    Hi April  it should be possible to check in  ...
# ..                                                 ...
# 293   I m very sorry for the frustration  Some fare...
# 294   Hi James   I m very sorry to hear about your ...
# 295  Tui infinity and beyond  Tui Travel s digital ...
# 296                                   #SisterGoals  MM
# 297   Hi  sorry to hear this  We have strict baggag...
# 298   James  once you selected checked in bag you c...
# 299   Hi Jane  we re very sorry for the inconvenien...
# 300   Hello  AC   from Delhi has since arrived in T...
# 301   Hi  Filip  the Wizz Discount Club should be a...
# 302                               Yes  that s correct
# 303   So sorry for falling short  Drake  All Southw...
# 304   We re very sorry for the challenging start to...
# 305   Hi Nanny  we don t price match I m afraid  Ap...
# 306                 That s a fantastic #AAmericanView
# 307                            https   t co XoBKWjr ge
# 308   If you booked with  in the U K   we are sure ...
# 309   Hello Emerson  we invite you to contact our R...
# 310   Darn  we re sorry to hear that  Please DM you...
# 311   Thank you for your patience  We apologize for...
# 312       Name Surname  Date of birth and email add...
# 313   Only for American Airlines flights  they must...
# 314   Hi Rhys  my colleague  will be able to help w...
# 315   We ve got the pedal to the metal and we ll do...
# 316   Hello  We don t like that you ve had a negati...
# 317   Hello Bob  once again we apologize for the in...
# 318                 I ll work on that for ya     Laura
# 319  RT   Tui Travel reports record results   pc ju...
# 320  #TUIresults in detail  focus on #cruises  Stro...
# 321   Please advise your full name  email and posta...
# 322   Hi Nicol s  Indicate us please your booking r...
#
#                                            Tidy_Tweets  Unnamed: 5  \
# 0    there best team assist contact centr fee appli...         NaN
# 1    aw sorri hear about that pleas your reserv inf...         NaN
# 2    #namibia melissa anna mari found immedi after ...         NaN
# 3    sorri hear thi peter would recommend phone bag...         NaN
# 4    #tuiresult show signific growth custom number ...         NaN
# 5    olan pleas hear thi feedback realli sorri same...         NaN
# 6    there will open schedul sale through januari t...         NaN
# 7              sorri hear that hope again futur jasmin         NaN
# 8    charlott thank get touch sorri that your fligh...         NaN
# 9    sorri disrupt shea send over your confirm numb...         NaN
# 10   that disappoint issu credit inconveni your let...         NaN
# 11   perfect plate enjoy have loung bambang again soon         NaN
# 12   thought with walter keep fight champ your corn...         NaN
# 13   launch brand investor relat briefcas iphon ipa...         NaN
# 14   love have with will gladli pass your kudo reco...         NaN
# 15   hello sorri inconveni pleas send privat messag...         NaN
# 16   thank confirm thi with emma taken look into th...         NaN
# 17   sorri hear about frustrat like share more plea...         NaN
# 18   thank get back would recommend speak custom se...         NaN
# 19   want custom feel welcom each everi time they w...         NaN
# 20   laura cancel individu from book split across o...         NaN
# 21   famili holiday associ launch campaign help dis...         NaN
# 22   your queri regard your trip pleas includ refer...         NaN
# 23   thi what like hear jimmi pleas your book refer...         NaN
# 24   sorri extra travel time today appreci your pat...         NaN
# 25   hello problem send confirm your full name date...         NaN
# 26   jose sinc those servic differ abl chang check ...         NaN
# 27   justin thank get touch actual abl which aircra...         NaN
# 28                   pleas your book detail advis rose         NaN
# 29   april should possibl check could send with you...         NaN
# ..                                                 ...         ...
# 293  veri sorri frustrat some fare such saver fare ...         NaN
# 294  jame veri sorri hear about your delay pleas li...         NaN
# 295   infin beyond travel digit transform http xdysnhi         NaN
# 296                                          #sistergo         NaN
# 297  sorri hear thi have strict baggag polici varie...         NaN
# 298  jame onc select check chang prioriti board ser...         NaN
# 299     jane veri sorri inconveni pleas further assist         NaN
# 300       hello from delhi sinc arriv toronto thi morn         NaN
# 301  filip wizz discount club should activ pleas ch...         NaN
# 302                                       that correct         NaN
# 303  sorri fall short drake southwest airlin employ...         NaN
# 304  veri sorri challeng start your welcom your con...         NaN
# 305  nanni price match afraid apolog disappoint hop...         NaN
# 306                        that fantast #aamericanview         NaN
# 307                                       http xobkwjr         NaN
# 308                book with sure they will happi help         NaN
# 309  hello emerson invit contact reserv team direct...         NaN
# 310  darn sorri hear that pleas your confirm code h...         NaN
# 311  thank your patienc apolog delay respons team w...         NaN
# 312  name surnam date birth email address onc have ...         NaN
# 313  onli american airlin flight they must book htt...         NaN
# 314    rhi colleagu will abl help with your book thank         NaN
# 315                      pedal metal make your connect         NaN
# 316  hello like that neg experi with pleas your res...         NaN
# 317  hello onc again apolog inconveni caus even tho...         NaN
# 318                                    work that laura         NaN
# 319  travel report record result jump profit peter ...         NaN
# 320  #tuiresult detail focu #cruis strong growth pa...         NaN
# 321  pleas advis your full name email postal addres...         NaN
# 322      nicol indic pleas your book refer privat help         NaN
#
#      0-apologize, 1-rectify, 2-supportive/helpful, 3-appreciate, 4 - misc.  \
# 0                                                  NaN
# 1                                                    -
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN
# 300                                                NaN
# 301                                                NaN
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
# 307                                                NaN
# 308                                                NaN
# 309                                                NaN
# 310                                                NaN
# 311                                                NaN
# 312                                                NaN
# 313                                                NaN
# 314                                                NaN
# 315                                                NaN
# 316                                                NaN
# 317                                                NaN
# 318                                                NaN
# 319                                                NaN
# 320                                                NaN
# 321                                                NaN
# 322                                                NaN
#
#     Rating 0-neg, 1-neu, 2-pos                                    sentiment
# 0        H                 NaN                                   (1.0, 0.3)
# 1        U                 NaN                                  (-0.5, 1.0)
# 2        N                 NaN                                   (0.0, 0.0)
# 3        U                 NaN                  (-0.04999999999999999, 0.7)
# 4        N                 NaN                               (0.375, 0.875)
# 5        U                 NaN    (0.22857142857142856, 0.6392857142857143)
# 6        N                 NaN    (0.06666666666666668, 0.3066666666666667)
# 7        U                 NaN                              (-0.25, 0.5625)
# 8        U                 NaN                (-0.14166666666666666, 0.525)
# 9        U                 NaN                                  (-0.5, 1.0)
# 10       U                 NaN                                  (-0.6, 0.7)
# 11       N                 NaN                                   (0.5, 0.7)
# 12       N                 NaN                               (0.175, 0.275)
# 13       N                 NaN   (0.13636363636363635, 0.45454545454545453)
# 14       N                 NaN                    (0.6, 0.8333333333333334)
# 15       U                 NaN   (-0.05000000000000001, 0.6416666666666667)
# 16       H                 NaN  (-0.08499999999999999, 0.41500000000000004)
# 17       U                 NaN                                  (0.0, 0.75)
# 18       H                 NaN               (0.22499999999999998, 0.25625)
# 19       H                 NaN                                   (0.8, 0.9)
# 20       H                 NaN                            (-0.0625, 0.3875)
# 21       N                 NaN                                   (0.0, 0.0)
# 22       H                 NaN                                   (0.1, 0.4)
# 23       U                 NaN                                 (0.35, 0.55)
# 24       U                 NaN                                (-0.25, 0.55)
# 25       H                 NaN                               (0.475, 0.775)
# 26       H                 NaN                               (0.25, 0.6125)
# 27       H                 NaN  (-0.024999999999999994, 0.4784722222222222)
# 28       H                 NaN                                  (0.6, 0.95)
# 29       H                 NaN                               (0.175, 0.775)
# ..     ...                 ...                                          ...
# 293      U                 NaN                               (-0.325, 0.75)
# 294      U                 NaN                  (-0.15, 0.7333333333333334)
# 295      N                 NaN                                   (0.0, 0.0)
# 296      N                 NaN                                   (0.0, 0.0)
# 297      U                 NaN    (-0.3333333333333333, 0.6666666666666666)
# 298      H                 NaN                                   (0.0, 1.0)
# 299      U                 NaN                               (-0.325, 0.75)
# 300      H                 NaN                                   (0.0, 0.0)
# 301      H                 NaN                                   (0.0, 0.0)
# 302      H                 NaN                                   (0.0, 0.0)
# 303      U                 NaN   (-0.05416666666666666, 0.6833333333333332)
# 304      U                 NaN    (0.21666666666666667, 0.9666666666666667)
# 305      U                 NaN    (-0.2333333333333333, 0.6833333333333332)
# 306      N                 NaN                                   (0.4, 0.9)
# 307      N                 NaN                                   (0.0, 0.0)
# 308      H                 NaN                   (0.65, 0.9444444444444444)
# 309      H                 NaN     (0.2333333333333333, 0.6166666666666667)
# 310      U                 NaN                                  (-0.5, 1.0)
# 311      U                 NaN                                   (0.0, 0.0)
# 312      H                 NaN                                   (0.0, 1.0)
# 313      H                 NaN                                   (0.0, 0.5)
# 314      H                 NaN                               (0.35, 0.4125)
# 315      H                 NaN                                   (0.0, 0.0)
# 316      U                 NaN                                  (-0.3, 0.4)
# 317      U                 NaN                                   (0.0, 0.0)
# 318      H                 NaN                                   (0.0, 0.0)
# 319      N                 NaN                                 (-0.05, 0.4)
# 320      N                 NaN     (0.5916666666666667, 0.8416666666666666)
# 321      H                 NaN    (0.16499999999999998, 0.6599999999999999)
# 322      H                 NaN                                 (0.0, 0.375)
#
# [323 rows x 10 columns]

# %%
'''Vader from nltk for sentiment analysis
Code was used from:
http://www.nltk.org/howto/sentiment.html
https://stackoverflow.com/questions/57803412/applying-sentimentintensityanalyzer-function-on-each-row-of-the-dataframe-prov
http://t-redactyl.io/blog/2017/04/using-vader-to-handle-sentiment-analysis-with-social-media-text.html
https://stackoverflow.com/questions/52323299/python-return-elif-statement
'''


nltk.download('vader_lexicon') #download if don't have vader
from nltk.sentiment.vader import SentimentIntensityAnalyzer


def get_sentiment(row, **kwargs):
    sid = SentimentIntensityAnalyzer()
    sentiment_score = sid.polarity_scores(row)
    positive_meter = sentiment_score['pos']
    negative_meter = sentiment_score['neg']
    neutral_meter = sentiment_score['neu']
    compound_meter = sentiment_score['compound']
    
    if kwargs['k'] == 'positive':
        return positive_meter
    elif kwargs['k'] == 'negative':
        return negative_meter
    elif kwargs['k'] == 'neutral':
        return neutral_meter
    else:
        return compound_meter

#replace null values with empty space
noNull = df['Text'].fillna("")

#tokenize tweets
tokenized_tweet = noNull.apply(lambda x: x.split())

#put list back together
for i in range(len(tokenized_tweet)):
    tokenized_tweet[i] = ' '.join(tokenized_tweet[i])

df['Positive'] = tokenized_tweet.apply(get_sentiment, k= 'positive')
df['Negative'] = tokenized_tweet.apply(get_sentiment, k= 'negative')
df['Neutral'] = tokenized_tweet.apply(get_sentiment, k = 'neutral')
df['Compound'] = tokenized_tweet.apply(get_sentiment, k = 'compound')

df
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#      Unnamed: 0  number keyword  \
# 0      0.943430   65789      TT
# 1      0.970177   49400      NK
# 2      0.143541   60959     TOM
# 3      0.360187   77607      VA
# 4      0.779308   58487     TOM
# 5      0.359184   77943      VA
# 6      0.153355   86771      WN
# 7      0.788929   46885      LS
# 8      0.909354   22436      BE
# 9      0.094547   72338      UA
# 10     0.160353   16399      B6
# 11     0.227760   52091      QF
# 12     0.629340   65344      TT
# 13     0.189803   60377     TOM
# 14     0.918695    1581      AA
# 15     0.502972   54854      TO
# 16     0.216359   22399      BE
# 17     0.409520   15645      AS
# 18     0.910300   45944      LS
# 19     0.096877    5540      AA
# 20     0.536603   45306      LS
# 21     0.131978   62805     TOM
# 22     0.171452   12373      AF
# 23     0.951226   52094      QF
# 24     0.668162     811      AA
# 25     0.806601   11809      AF
# 26     0.661338   83304      W6
# 27     0.967721   68383      U2
# 28     0.667780    7503      AC
# 29     0.169100   55744      TO
# ..          ...     ...     ...
# 293    0.713540   14489      AS
# 294    0.771143   48281      LS
# 295    0.367883   60048     TOM
# 296    0.181775   77281      VA
# 297    0.991126   65130      TT
# 298    0.243927   84326      W6
# 299    0.280581   33984      FR
# 300    0.332174    7005      AC
# 301    0.648780   84521      W6
# 302    0.626496   84160      W6
# 303    0.662308   87809      WN
# 304    0.570786   88396      WN
# 305    0.088233   45519      LS
# 306    0.412121    5212      AA
# 307    0.932134   16202      B6
# 308    0.363049   61827     TOM
# 309    0.272725    7605      AC
# 310    0.587596   18822      B6
# 311    0.520768   50257      NK
# 312    0.826819   11803      AF
# 313    0.971511   15251      AS
# 314    0.079147   63374     TOM
# 315    0.117393    5936      AA
# 316    0.769756   50964      NK
# 317    0.519524   80292      VY
# 318    0.510298   15909      AS
# 319    0.703480   63020     TOM
# 320    0.085105   58046     TOM
# 321    0.260572   42866      LH
# 322    0.299976   76133      UX
#
#                                                   Text  \
# 0     Hi there  the best team to assist you is our ...
# 1     We re awfully sorry to hear about that  Pleas...
# 2    RT   In #Namibia  Melissa and Anna Marie found...
# 3     We re sorry to hear this Peter  We would reco...
# 4    RT   The Q  #TUIResults are out and show signi...
# 5     Hi Olan  we are so pleased to hear this feedb...
# 6     Hi there  On May          we will open our sc...
# 7     Sorry to hear that  We do hope to see you aga...
# 8     Hi Charlotte  thanks for getting in touch  I ...
# 9     We re sorry for the disruption  Shea  Can you...
# 10    That s disappointing  We can issue a     cred...
# 11    Perfection on a plate  We enjoyed having you ...
# 12    Our thoughts are with you Walter  keep fighti...
# 13   We ve launched our brand new Investor Relation...
# 14    We love having you fly with us and will gladl...
# 15    Hello  I am sorry for the inconveniences  Can...
# 16    Thanks for confirming this with me Emma  I ve...
# 17    We re sorry to hear about any frustration  If...
# 18    Thanks for getting back to us  we would recom...
# 19    We want all of our customers to feel welcome ...
# 20    Hi Laura  If you don t cancel the individual ...
# 21   Family Holiday Association launches     for   ...
# 22        If your query is regarding your trip  ple...
# 23    This isn t what we like to hear Jimmy  Can yo...
# 24    We re so sorry for the extra travel time toda...
# 25    Hello   not a problem  Send us a DM confirmin...
# 26    Hey Jose  since those services are different ...
# 27    Hi Justin  thanks for getting in touch  I m n...
# 28    Please DM us your booking details so we may a...
# 29    Hi April  it should be possible to check in  ...
# ..                                                 ...
# 293   I m very sorry for the frustration  Some fare...
# 294   Hi James   I m very sorry to hear about your ...
# 295  Tui infinity and beyond  Tui Travel s digital ...
# 296                                   #SisterGoals  MM
# 297   Hi  sorry to hear this  We have strict baggag...
# 298   James  once you selected checked in bag you c...
# 299   Hi Jane  we re very sorry for the inconvenien...
# 300   Hello  AC   from Delhi has since arrived in T...
# 301   Hi  Filip  the Wizz Discount Club should be a...
# 302                               Yes  that s correct
# 303   So sorry for falling short  Drake  All Southw...
# 304   We re very sorry for the challenging start to...
# 305   Hi Nanny  we don t price match I m afraid  Ap...
# 306                 That s a fantastic #AAmericanView
# 307                            https   t co XoBKWjr ge
# 308   If you booked with  in the U K   we are sure ...
# 309   Hello Emerson  we invite you to contact our R...
# 310   Darn  we re sorry to hear that  Please DM you...
# 311   Thank you for your patience  We apologize for...
# 312       Name Surname  Date of birth and email add...
# 313   Only for American Airlines flights  they must...
# 314   Hi Rhys  my colleague  will be able to help w...
# 315   We ve got the pedal to the metal and we ll do...
# 316   Hello  We don t like that you ve had a negati...
# 317   Hello Bob  once again we apologize for the in...
# 318                 I ll work on that for ya     Laura
# 319  RT   Tui Travel reports record results   pc ju...
# 320  #TUIresults in detail  focus on #cruises  Stro...
# 321   Please advise your full name  email and posta...
# 322   Hi Nicol s  Indicate us please your booking r...
#
#                                            Tidy_Tweets  Unnamed: 5  \
# 0    there best team assist contact centr fee appli...         NaN
# 1    aw sorri hear about that pleas your reserv inf...         NaN
# 2    #namibia melissa anna mari found immedi after ...         NaN
# 3    sorri hear thi peter would recommend phone bag...         NaN
# 4    #tuiresult show signific growth custom number ...         NaN
# 5    olan pleas hear thi feedback realli sorri same...         NaN
# 6    there will open schedul sale through januari t...         NaN
# 7              sorri hear that hope again futur jasmin         NaN
# 8    charlott thank get touch sorri that your fligh...         NaN
# 9    sorri disrupt shea send over your confirm numb...         NaN
# 10   that disappoint issu credit inconveni your let...         NaN
# 11   perfect plate enjoy have loung bambang again soon         NaN
# 12   thought with walter keep fight champ your corn...         NaN
# 13   launch brand investor relat briefcas iphon ipa...         NaN
# 14   love have with will gladli pass your kudo reco...         NaN
# 15   hello sorri inconveni pleas send privat messag...         NaN
# 16   thank confirm thi with emma taken look into th...         NaN
# 17   sorri hear about frustrat like share more plea...         NaN
# 18   thank get back would recommend speak custom se...         NaN
# 19   want custom feel welcom each everi time they w...         NaN
# 20   laura cancel individu from book split across o...         NaN
# 21   famili holiday associ launch campaign help dis...         NaN
# 22   your queri regard your trip pleas includ refer...         NaN
# 23   thi what like hear jimmi pleas your book refer...         NaN
# 24   sorri extra travel time today appreci your pat...         NaN
# 25   hello problem send confirm your full name date...         NaN
# 26   jose sinc those servic differ abl chang check ...         NaN
# 27   justin thank get touch actual abl which aircra...         NaN
# 28                   pleas your book detail advis rose         NaN
# 29   april should possibl check could send with you...         NaN
# ..                                                 ...         ...
# 293  veri sorri frustrat some fare such saver fare ...         NaN
# 294  jame veri sorri hear about your delay pleas li...         NaN
# 295   infin beyond travel digit transform http xdysnhi         NaN
# 296                                          #sistergo         NaN
# 297  sorri hear thi have strict baggag polici varie...         NaN
# 298  jame onc select check chang prioriti board ser...         NaN
# 299     jane veri sorri inconveni pleas further assist         NaN
# 300       hello from delhi sinc arriv toronto thi morn         NaN
# 301  filip wizz discount club should activ pleas ch...         NaN
# 302                                       that correct         NaN
# 303  sorri fall short drake southwest airlin employ...         NaN
# 304  veri sorri challeng start your welcom your con...         NaN
# 305  nanni price match afraid apolog disappoint hop...         NaN
# 306                        that fantast #aamericanview         NaN
# 307                                       http xobkwjr         NaN
# 308                book with sure they will happi help         NaN
# 309  hello emerson invit contact reserv team direct...         NaN
# 310  darn sorri hear that pleas your confirm code h...         NaN
# 311  thank your patienc apolog delay respons team w...         NaN
# 312  name surnam date birth email address onc have ...         NaN
# 313  onli american airlin flight they must book htt...         NaN
# 314    rhi colleagu will abl help with your book thank         NaN
# 315                      pedal metal make your connect         NaN
# 316  hello like that neg experi with pleas your res...         NaN
# 317  hello onc again apolog inconveni caus even tho...         NaN
# 318                                    work that laura         NaN
# 319  travel report record result jump profit peter ...         NaN
# 320  #tuiresult detail focu #cruis strong growth pa...         NaN
# 321  pleas advis your full name email postal addres...         NaN
# 322      nicol indic pleas your book refer privat help         NaN
#
#      0-apologize, 1-rectify, 2-supportive/helpful, 3-appreciate, 4 - misc.  \
# 0                                                  NaN
# 1                                                    -
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN
# 300                                                NaN
# 301                                                NaN
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
# 307                                                NaN
# 308                                                NaN
# 309                                                NaN
# 310                                                NaN
# 311                                                NaN
# 312                                                NaN
# 313                                                NaN
# 314                                                NaN
# 315                                                NaN
# 316                                                NaN
# 317                                                NaN
# 318                                                NaN
# 319                                                NaN
# 320                                                NaN
# 321                                                NaN
# 322                                                NaN
#
#     Rating 0-neg, 1-neu, 2-pos                                    sentiment  \
# 0        H                 NaN                                   (1.0, 0.3)
# 1        U                 NaN                                  (-0.5, 1.0)
# 2        N                 NaN                                   (0.0, 0.0)
# 3        U                 NaN                  (-0.04999999999999999, 0.7)
# 4        N                 NaN                               (0.375, 0.875)
# 5        U                 NaN    (0.22857142857142856, 0.6392857142857143)
# 6        N                 NaN    (0.06666666666666668, 0.3066666666666667)
# 7        U                 NaN                              (-0.25, 0.5625)
# 8        U                 NaN                (-0.14166666666666666, 0.525)
# 9        U                 NaN                                  (-0.5, 1.0)
# 10       U                 NaN                                  (-0.6, 0.7)
# 11       N                 NaN                                   (0.5, 0.7)
# 12       N                 NaN                               (0.175, 0.275)
# 13       N                 NaN   (0.13636363636363635, 0.45454545454545453)
# 14       N                 NaN                    (0.6, 0.8333333333333334)
# 15       U                 NaN   (-0.05000000000000001, 0.6416666666666667)
# 16       H                 NaN  (-0.08499999999999999, 0.41500000000000004)
# 17       U                 NaN                                  (0.0, 0.75)
# 18       H                 NaN               (0.22499999999999998, 0.25625)
# 19       H                 NaN                                   (0.8, 0.9)
# 20       H                 NaN                            (-0.0625, 0.3875)
# 21       N                 NaN                                   (0.0, 0.0)
# 22       H                 NaN                                   (0.1, 0.4)
# 23       U                 NaN                                 (0.35, 0.55)
# 24       U                 NaN                                (-0.25, 0.55)
# 25       H                 NaN                               (0.475, 0.775)
# 26       H                 NaN                               (0.25, 0.6125)
# 27       H                 NaN  (-0.024999999999999994, 0.4784722222222222)
# 28       H                 NaN                                  (0.6, 0.95)
# 29       H                 NaN                               (0.175, 0.775)
# ..     ...                 ...                                          ...
# 293      U                 NaN                               (-0.325, 0.75)
# 294      U                 NaN                  (-0.15, 0.7333333333333334)
# 295      N                 NaN                                   (0.0, 0.0)
# 296      N                 NaN                                   (0.0, 0.0)
# 297      U                 NaN    (-0.3333333333333333, 0.6666666666666666)
# 298      H                 NaN                                   (0.0, 1.0)
# 299      U                 NaN                               (-0.325, 0.75)
# 300      H                 NaN                                   (0.0, 0.0)
# 301      H                 NaN                                   (0.0, 0.0)
# 302      H                 NaN                                   (0.0, 0.0)
# 303      U                 NaN   (-0.05416666666666666, 0.6833333333333332)
# 304      U                 NaN    (0.21666666666666667, 0.9666666666666667)
# 305      U                 NaN    (-0.2333333333333333, 0.6833333333333332)
# 306      N                 NaN                                   (0.4, 0.9)
# 307      N                 NaN                                   (0.0, 0.0)
# 308      H                 NaN                   (0.65, 0.9444444444444444)
# 309      H                 NaN     (0.2333333333333333, 0.6166666666666667)
# 310      U                 NaN                                  (-0.5, 1.0)
# 311      U                 NaN                                   (0.0, 0.0)
# 312      H                 NaN                                   (0.0, 1.0)
# 313      H                 NaN                                   (0.0, 0.5)
# 314      H                 NaN                               (0.35, 0.4125)
# 315      H                 NaN                                   (0.0, 0.0)
# 316      U                 NaN                                  (-0.3, 0.4)
# 317      U                 NaN                                   (0.0, 0.0)
# 318      H                 NaN                                   (0.0, 0.0)
# 319      N                 NaN                                 (-0.05, 0.4)
# 320      N                 NaN     (0.5916666666666667, 0.8416666666666666)
# 321      H                 NaN    (0.16499999999999998, 0.6599999999999999)
# 322      H                 NaN                                 (0.0, 0.375)
#
#      Positive  Negative  Neutral  Compound
# 0       0.174     0.000    0.826    0.6369
# 1       0.096     0.067    0.837    0.1796
# 2       0.000     0.000    1.000    0.0000
# 3       0.066     0.034    0.899    0.2960
# 4       0.180     0.000    0.820    0.5267
# 5       0.152     0.029    0.819    0.7749
# 6       0.050     0.000    0.950    0.3182
# 7       0.169     0.076    0.756    0.3818
# 8       0.104     0.149    0.746   -0.1027
# 9       0.056     0.165    0.779   -0.3612
# 10      0.099     0.217    0.684   -0.4767
# 11      0.333     0.000    0.667    0.7906
# 12      0.185     0.077    0.738    0.5423
# 13      0.067     0.000    0.933    0.1280
# 14      0.368     0.000    0.632    0.8720
# 15      0.169     0.026    0.805    0.7269
# 16      0.105     0.117    0.778    0.1045
# 17      0.199     0.120    0.681    0.4391
# 18      0.229     0.000    0.771    0.8074
# 19      0.306     0.000    0.694    0.7783
# 20      0.000     0.057    0.943   -0.1280
# 21      0.256     0.128    0.616    0.4019
# 22      0.161     0.000    0.839    0.5859
# 23      0.213     0.000    0.787    0.7964
# 24      0.164     0.106    0.730    0.2403
# 25      0.163     0.000    0.837    0.6197
# 26      0.101     0.000    0.899    0.5719
# 27      0.124     0.042    0.834    0.5911
# 28      0.187     0.000    0.813    0.3182
# 29      0.154     0.137    0.709   -0.0772
# ..        ...       ...      ...       ...
# 293     0.000     0.216    0.784   -0.5709
# 294     0.168     0.114    0.718    0.4417
# 295     0.000     0.000    1.000    0.0000
# 296     0.000     0.000    1.000    0.0000
# 297     0.000     0.056    0.944   -0.0772
# 298     0.000     0.000    1.000    0.0000
# 299     0.119     0.211    0.670   -0.2006
# 300     0.000     0.000    1.000    0.0000
# 301     0.234     0.000    0.766    0.6696
# 302     0.574     0.000    0.426    0.4019
# 303     0.252     0.108    0.640    0.8294
# 304     0.146     0.039    0.815    0.5118
# 305     0.410     0.070    0.520    0.9091
# 306     0.643     0.000    0.357    0.5574
# 307     0.000     0.000    1.000    0.0000
# 308     0.401     0.000    0.599    0.8271
# 309     0.078     0.000    0.922    0.1531
# 310     0.124     0.070    0.806    0.2500
# 311     0.133     0.049    0.817    0.4404
# 312     0.073     0.000    0.927    0.2960
# 313     0.000     0.000    1.000    0.0000
# 314     0.337     0.000    0.663    0.6808
# 315     0.000     0.000    1.000    0.0000
# 316     0.168     0.130    0.702    0.0258
# 317     0.063     0.175    0.762   -0.3612
# 318     0.000     0.000    1.000    0.0000
# 319     0.116     0.000    0.884    0.4404
# 320     0.431     0.000    0.569    0.8442
# 321     0.120     0.000    0.880    0.6124
# 322     0.263     0.000    0.737    0.6124
#
# [323 rows x 14 columns]

# %%
##Cross Validation

from sklearn.model_selection import KFold # import KFold

X=np.array(df['Text'])
y=np.array(df['Rating'])

kf = KFold(n_splits=10) # Define the split - into 2 folds 
kf.get_n_splits(X) # returns the number of splitting iterations in the cross-validator

print(kf)
# Out:
# KFold(n_splits=10, random_state=None, shuffle=False)

# %%
#Function to Train & Run the model
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer

vect = CountVectorizer(stop_words='english', ngram_range = (1,1), max_df = .80, min_df = 1)
vectorizer = TfidfVectorizer(min_df=15)
def run_model(model,modelType):
    scores=list()
    scores_std=list()
    C_s = np.logspace(-10, 0, 10)
    for train_index, test_index in kf.split(X):

        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        if modelType == "KNN":
            #vectorizer = TfidfVectorizer(min_df=15)
            X_train_dtm = vectorizer.fit_transform(X_train)
            X_test_dtm = vectorizer.transform(X_test)
            
        else:
            #vect = CountVectorizer(stop_words='english', ngram_range = (1,1), max_df = .80, min_df = 1)
            #Using training data to transform text into counts of features for each message
            vect.fit(X_train)
            X_train_dtm = vect.transform(X_train) 
            X_test_dtm = vect.transform(X_test)

        #Fit Model
        model.fit(X_train_dtm, y_train)
        y_pred = model.predict(X_test_dtm)

        this_scores=metrics.accuracy_score(y_test,y_pred)*100
        scores.append(np.mean(this_scores))
        scores_std.append(np.std(this_scores))
        
        print('Accuracy Score: ',this_scores,'%',sep='')
        print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')
    return scores

# %%
'''KNN model'''
from sklearn.neighbors import KNeighborsClassifier

#KNN Classifiers
KNN = KNeighborsClassifier(n_neighbors = 1)
scores=run_model(KNN,"KNN")

print('\nK Nearest Neighbors (NN = 1)')
print('Accuracy Score: ',np.mean(scores),'%',sep='')
#print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')
# Out:
# Accuracy Score: 78.78787878787878%
# Confusion Matrix:
# [[10  0  2]
#  [ 1  6  1]
#  [ 1  2 10]]
# Accuracy Score: 51.515151515151516%
# Confusion Matrix:
# [[7 4 1]
#  [4 2 2]
#  [3 2 8]]
# Accuracy Score: 66.66666666666666%
# Confusion Matrix:
# [[10  2  0]
#  [ 2  3  3]
#  [ 4  0  9]]
# Accuracy Score: 65.625%
# Confusion Matrix:
# [[10  4  2]
#  [ 1  3  0]
#  [ 3  1  8]]
# Accuracy Score: 56.25%
# Confusion Matrix:
# [[7 3 3]
#  [2 3 1]
#  [3 2 8]]
# Accuracy Score: 78.125%
# Confusion Matrix:
# [[14  2  3]
#  [ 1  6  0]
#  [ 1  0  5]]
# Accuracy Score: 65.625%
# Confusion Matrix:
# [[5 4 2]
#  [1 7 0]
#  [3 1 9]]
# Accuracy Score: 65.625%
# Confusion Matrix:
# [[8 1 5]
#  [3 4 0]
#  [1 1 9]]
# Accuracy Score: 62.5%
# Confusion Matrix:
# [[10  1  5]
#  [ 3  4  0]
#  [ 1  2  6]]
# Accuracy Score: 71.875%
# Confusion Matrix:
# [[ 9  2  3]
#  [ 1  4  1]
#  [ 2  0 10]]
#
# K Nearest Neighbors (NN = 1)
# Accuracy Score: 66.2594696969697%

# %%
'''Logistic Regression'''

from sklearn.linear_model import LogisticRegression

#logistic regression
LR = LogisticRegression()
scores=run_model(LR,"LR")

print('\nLogistic Regression')
print('Accuracy Score: ',np.mean(scores),'%',sep='')
# Out:
# Accuracy Score:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 87.87878787878788%
# Confusion Matrix:
# [[11  0  1]
#  [ 2  6  0]
#  [ 1  0 12]]
# Accuracy Score: 78.78787878787878%
# Confusion Matrix:
# [[11  1  0]
#  [ 3  5  0]
#  [ 2  1 10]]
# Accuracy Score: 75.75757575757575%
# Confusion Matrix:
# [[10  2  0]
#  [ 3  4  1]
#  [ 2  0 11]]
# Accuracy Score: 90.625%
# Confusion Matrix:
# [[14  1  1]
#  [ 1  3  0]
#  [ 0  0 12]]
# Accuracy Score: 84.375%
# Confusion Matrix:
# [[11  2  0]
#  [ 2  4  0]
#  [ 1  0 12]]
# Accuracy Score: 90.625%
# Confusion Matrix:
# [[17  1  1]
#  [ 1  6  0]
#  [ 0  0  6]]
# Accuracy Score: 87.5%
# Confusion Matrix:
# [[10  1  0]
#  [ 2  6  0]
#  [ 1  0 12]]
# Accuracy Score: 90.625%
# Confusion Matrix:
# [[14  0  0]
#  [ 0  7  0]
#  [ 1  2  8]]
# Accuracy Score: 78.125%
# Confusion Matrix:
# [[12  3  1]
#  [ 2  5  0]
#  [ 1  0  8]]
# Accuracy Score: 96.875%
# Confusion Matrix:
# [[13  1  0]
#  [ 0  6  0]
#  [ 0  0 12]]
#
# Logistic Regression
# Accuracy Score: 86.11742424242424%

# %%
'''Support Vector Machine'''
from sklearn.svm import LinearSVC

#SVM
SVM = LinearSVC(penalty='l2', loss='squared_hinge')
#kernel = 'linear', random_state = 0

scores=run_model(SVM,"SVM")
print('\nSupport Vector Machine')
print('Accuracy Score: ',np.mean(scores),'%',sep='')
# Out:
# Accuracy Score: 75.75757575757575%
# Confusion Matrix:
# [[ 9  1  2]
#  [ 2  6  0]
#  [ 3  0 10]]
# Accuracy Score: 75.75757575757575%
# Confusion Matrix:
# [[10  2  0]
#  [ 3  5  0]
#  [ 2  1 10]]
# Accuracy Score: 81.81818181818183%
# Confusion Matrix:
# [[10  2  0]
#  [ 1  6  1]
#  [ 2  0 11]]
# Accuracy Score: 87.5%
# Confusion Matrix:
# [[13  2  1]
#  [ 1  3  0]
#  [ 0  0 12]]
# Accuracy Score: 81.25%
# Confusion Matrix:
# [[ 9  4  0]
#  [ 1  5  0]
#  [ 1  0 12]]
# Accuracy Score: 81.25%
# Confusion Matrix:
# [[15  3  1]
#  [ 1  6  0]
#  [ 1  0  5]]
# Accuracy Score: 84.375%
# Confusion Matrix:
# [[ 9  1  1]
#  [ 2  6  0]
#  [ 1  0 12]]
# Accuracy Score: 90.625%
# Confusion Matrix:
# [[14  0  0]
#  [ 0  7  0]
#  [ 1  2  8]]
# Accuracy Score: 81.25%
# Confusion Matrix:
# [[12  3  1]
#  [ 1  6  0]
#  [ 1  0  8]]
# Accuracy Score: 93.75%
# Confusion Matrix:
# [[12  1  1]
#  [ 0  6  0]
#  [ 0  0 12]]
#
# Support Vector Machine
# Accuracy Score: 83.33333333333333%

# %%
'''Random Forest Classifier'''
from sklearn.ensemble import RandomForestClassifier

RFC = RandomForestClassifier(n_estimators = 3,random_state=0)
scores=run_model(RFC,"RFC")

print('\n Random Forest Classifier')
print('Accuracy Score: ',np.mean(scores),'%',sep='')
# Out:
# Accuracy Score: 69.6969696969697%
# Confusion Matrix:
# [[11  0  1]
#  [ 6  2  0]
#  [ 3  0 10]]
# Accuracy Score: 72.72727272727273%
# Confusion Matrix:
# [[10  1  1]
#  [ 5  3  0]
#  [ 0  2 11]]
# Accuracy Score: 60.60606060606061%
# Confusion Matrix:
# [[11  0  1]
#  [ 7  1  0]
#  [ 5  0  8]]
# Accuracy Score: 78.125%
# Confusion Matrix:
# [[11  3  2]
#  [ 1  3  0]
#  [ 1  0 11]]
# Accuracy Score: 65.625%
# Confusion Matrix:
# [[10  0  3]
#  [ 4  1  1]
#  [ 3  0 10]]
# Accuracy Score: 59.375%
# Confusion Matrix:
# [[10  4  5]
#  [ 1  5  1]
#  [ 2  0  4]]
# Accuracy Score: 78.125%
# Confusion Matrix:
# [[11  0  0]
#  [ 7  1  0]
#  [ 0  0 13]]
# Accuracy Score: 78.125%
# Confusion Matrix:
# [[12  2  0]
#  [ 0  7  0]
#  [ 3  2  6]]
# Accuracy Score: 87.5%
# Confusion Matrix:
# [[16  0  0]
#  [ 4  3  0]
#  [ 0  0  9]]
# Accuracy Score: 68.75%
# Confusion Matrix:
# [[9 5 0]
#  [0 6 0]
#  [5 0 7]]
#
#  Random Forest Classifier
# Accuracy Score: 71.8655303030303%

# %%
'''Naive Bayes Model'''

from sklearn.naive_bayes import MultinomialNB

#Naive Bayes Model
NB = MultinomialNB()
scores=run_model(NB,"NB")

print('\nNaive Bayes')
print('Accuracy Score: ',np.mean(scores),'%',sep='')
# Out:
# Accuracy Score: 87.87878787878788%
# Confusion Matrix:
# [[11  0  1]
#  [ 2  5  1]
#  [ 0  0 13]]
# Accuracy Score: 66.66666666666666%
# Confusion Matrix:
# [[ 9  0  3]
#  [ 4  2  2]
#  [ 1  1 11]]
# Accuracy Score: 60.60606060606061%
# Confusion Matrix:
# [[ 7  1  4]
#  [ 3  2  3]
#  [ 2  0 11]]
# Accuracy Score: 75.0%
# Confusion Matrix:
# [[ 9  0  7]
#  [ 1  3  0]
#  [ 0  0 12]]
# Accuracy Score: 81.25%
# Confusion Matrix:
# [[11  0  2]
#  [ 3  2  1]
#  [ 0  0 13]]
# Accuracy Score: 65.625%
# Confusion Matrix:
# [[13  1  5]
#  [ 1  2  4]
#  [ 0  0  6]]
# Accuracy Score: 78.125%
# Confusion Matrix:
# [[10  0  1]
#  [ 5  2  1]
#  [ 0  0 13]]
# Accuracy Score: 87.5%
# Confusion Matrix:
# [[12  0  2]
#  [ 0  6  1]
#  [ 1  0 10]]
# Accuracy Score: 62.5%
# Confusion Matrix:
# [[10  0  6]
#  [ 1  2  4]
#  [ 1  0  8]]
# Accuracy Score: 90.625%
# Confusion Matrix:
# [[14  0  0]
#  [ 2  3  1]
#  [ 0  0 12]]
#
# Naive Bayes
# Accuracy Score: 75.57765151515152%

# %%
#Predict the Unlabled datset

X=np.array(df_new_data['Text'].values.astype('U'))
X_train_dtm = vect.transform(X) 

y_pred = SVM.predict(X_train_dtm)

print('\n SVM Regression',y_pred)
# Out:
#  SVM Regression ['N' 'H' 'H' ... 'H' 'N' 'U']

# %%
df_new_data["rating"]=y_pred
df_new_data.head()

df_new_data.to_csv(r'D:\Travelytics Project\Data\SA_Tweets_Predicted.csv')
